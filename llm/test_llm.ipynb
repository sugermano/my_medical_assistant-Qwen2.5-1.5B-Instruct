# %%
import sys
sys.path.append('D:/gitRepository/my_medical_assistant-Qwen2.5-1.5B-Instruct')
from zhipuai_llm import ZhipuAILLM

from dotenv import find_dotenv, load_dotenv
import os

_ = load_dotenv(find_dotenv())
api_key = os.environ['ZHIPUAI_API_KEY']
# api_key

# %%
llm = ZhipuAILLM(model="glm-4.6", zhipuai_api_key=api_key, temperature=0.1)
llm.invoke("你是谁")
# Out:
# a7db401f88674a27a06a5d4698e0550d.Vd0YaLGBb0cRHegy
# '\n我是GLM，由智谱AI开发的大语言模型。我通过大规模文本数据训练，能够理解和生成人类语言，为用户提供信息和帮助。\n\n我的设计目标是协助用户解答问题、提供创意建议和进行有意义的对话。我会持续学习和更新，以提供更准确、有用的信息。\n\n有什么我能帮你解答或探讨的话题吗？'
